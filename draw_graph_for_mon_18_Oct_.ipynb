# %% [markdown]
# <a href="https://colab.research.google.com/github/aliSaDmsCthesis/Notebooks/blob/main/draw_graph_for_mon_18_Oct_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt
import random
import networkx as nx

# %%
num_of_nodes = 5

# %%
G = nx.Graph()

itemsi = [f'i{i}' for i in range(1,num_of_nodes+1)]
itemsj = [f'j{i}' for i in range(1,num_of_nodes+1)]
itemsu = [f'u{i}' for i in range(1,num_of_nodes+1)]

G.add_nodes_from(itemsi + itemsj + itemsu )

colors_n = ['#f09409']*num_of_nodes + ['#00f4d0']*num_of_nodes + ['#ffb4d9']*num_of_nodes

# pos = nx.spring_layout(G) 
nx.draw(G, edge_color=colors_e,node_color=colors_n, pos=pos, width=weights,with_labels = True)
# nx.draw(G, edge_color=colors_e,node_color=colors_n ,width=weights,with_labels = True)
# plt.savefig('p1.png')

# %%
import random
# randomlist = []
edge_num = 15
for i in range(0,edge_num):
  a = random.randint(1,num_of_nodes)
  b = random.randint(1,num_of_nodes)
  a = f'i{a}'
  b = f'u{b}'
  G.add_edge(a , b ,color='blue',weight=2)


for i in range(0,edge_num):
  a = random.randint(1,num_of_nodes)
  b = random.randint(1,num_of_nodes)
  a = f'j{a}'
  b = f'u{b}'
  G.add_edge(a , b ,color='green',weight=2)

# G.add_edge(1,2,color='r',weight=2)
edges = G.edges()
colors_e = [G[u][v]['color'] for u,v in edges]
weights = [G[u][v]['weight'] for u,v in edges]

pos = nx.spring_layout(G) 
nx.draw(G, edge_color=colors_e,node_color=colors_n, pos=pos, width=weights,with_labels = True)
# nx.draw(G, edge_color=colors_e,node_color=colors_n ,width=weights,with_labels = True)
# plt.savefig('p2.png')

# %%
# pos = nx.spring_layout(G) 
nx.draw(G, edge_color=colors_e,node_color=colors_n, pos=pos, width=weights,with_labels = True)
# plt.savefig('p2.png')

# %%
G.add_edge('i3','j5' ,color='red',weight=6)

edges = G.edges()
colors_e = [G[u][v]['color'] for u,v in edges]
weights = [G[u][v]['weight'] for u,v in edges]

nx.draw(G, edge_color=colors_e,node_color=colors_n, pos=pos, width=weights,with_labels = True)
# nx.draw(G, edge_color=colors_e,node_color=colors_n ,width=weights,with_labels = True)
plt.savefig('p3.png')

# %%
G.add_edge('u2','u5' ,color='brown',weight=6)

edges = G.edges()
colors_e = [G[u][v]['color'] for u,v in edges]
weights = [G[u][v]['weight'] for u,v in edges]


# nx.draw(G, edge_color=colors_e,node_color=colors_n ,width=weights,with_labels = True)

# %%
nx.draw(G, edge_color=colors_e,node_color=colors_n, pos=pos, width=weights,with_labels = True)
# nx.draw(G, edge_color=colors_e,node_color=colors_n ,width=weights,with_labels = True)

# %%
# G.remove_edge('j2','j4')

G.add_edge('j2','j4' ,color='gray',weight=9 , linestyle= '--')

edges = G.edges()
colors_e = [G[u][v]['color'] for u,v in edges]
weights = [G[u][v]['weight'] for u,v in edges]

nx.draw(G, edge_color=colors_e,node_color=colors_n, pos=pos, width=weights,with_labels = True)

# %%
G1 = nx.Graph()

# itemsj = [f'j{i}' for i in range(1,num_of_nodes+1)]
# itemsu = [f'u{i}' for i in range(1,num_of_nodes+1)]

G1.add_nodes_from( itemsj + itemsu )

colors_n_2 = ['#00f4d0']*num_of_nodes + ['#ffb4d9']*num_of_nodes

for u,v in G.edges():
  if u in [f'i{i}' for i in range(1,num_of_nodes+1)] or v in [f'i{i}' for i in range(1,num_of_nodes+1)]:
    pass
  else:
    if u == 'u2' and v == 'u5':
      G1.add_edge('u2','u5' ,color='green',weight=6)
    elif u == 'j2' and v == 'j4':
      G1.add_edge('j2','j4' ,color='gray',weight=9)
    else:
      G1.add_edge(u,v,color = 'gray' , weight = 1)



# G.add_edge('i3','j5' ,color='red',weight=6)

edges = G1.edges()
colors_e_2 = [G1[u][v]['color'] for u,v in edges]
weights_2 = [G1[u][v]['weight'] for u,v in edges]

# %%
nx.draw(G1,pos=pos,edge_color=colors_e_2 , width=weights_2 , node_color=colors_n_2,with_labels = True)

# %%
G.edges()
# Out:
# EdgeView([('i1', 'u5'), ('i1', 'u1'), ('i2', 'u5'), ('i2', 'u1'), ('i3', 'u3'), ('i3', 'j5'), ('i4', 'u4'), ('i4', 'u1'), ('i4', 'u2'), ('i5', 'u1'), ('i5', 'u5'), ('i5', 'u3'), ('i5', 'u2'), ('j1', 'u4'), ('j2', 'u2'), ('j2', 'u5'), ('j2', 'u1'), ('j2', 'j4'), ('j3', 'u3'), ('j3', 'u1'), ('j4', 'u5'), ('j4', 'u4'), ('j5', 'u1'), ('j5', 'u4'), ('j5', 'u3'), ('u2', 'u5')])

# %% [markdown]
# #part 2

# %%
num_of_nodes = 10
G = nx.Graph()

itemsi = [f'i{i}' for i in range(1,num_of_nodes+1)]
itemsj = [f'j{i}' for i in range(1,num_of_nodes+1)]
itemsu = [f'u{i}' for i in range(1,num_of_nodes+1)]

G.add_nodes_from(itemsi + itemsj + itemsu )

colors_n = ['#f09409']*num_of_nodes + ['#00f4d0']*num_of_nodes + ['#ffb4d9']*num_of_nodes

# pos = nx.spring_layout(G) 
nx.draw(G, edge_color=colors_e,node_color=colors_n, width=weights,with_labels = True)

# %%
edge_num = 15
G.remove_edges_from(G.edges())

for i in range(0,edge_num):
  a = random.randint(1,num_of_nodes)
  b = random.randint(1,num_of_nodes)
  w = random.randint(1,10)
  a = f'j{a}'
  b = f'j{b}'
  G.add_edge(a , b ,color='green',weight=w)

for i in range(0,edge_num):
  a = random.randint(1,num_of_nodes)
  b = random.randint(1,num_of_nodes)
  w = random.randint(1,10)
  a = f'i{a}'
  b = f'i{b}'
  G.add_edge(a , b ,color='green',weight=w)

for i in range(0,edge_num):
  a = random.randint(1,num_of_nodes)
  b = random.randint(1,num_of_nodes)
  w = random.randint(1,10)
  a = f'u{a}'
  b = f'u{b}'
  G.add_edge(a , b ,color='green',weight=w)

pos = nx.spring_layout(G) 
nx.draw(G, edge_color=colors_e,node_color=colors_n, width=weights,with_labels = True)

# %%
  nx.draw_circular(G, node_color=colors_n, width=weights,with_labels = True)

# %%
G.add_edge('u1' , 'i7' ,color='red',weight=7)
G.add_edge('i7' , 'i1' ,color='red',weight=7)

edges = G.edges()
colors_e_2 = [G[u][v]['color'] for u,v in edges]
# weights = [G[u][v]['weight'] for u,v in edges]

nx.draw_circular(G, edge_color=colors_e_2, node_color=colors_n,with_labels = True)

# %%
G.add_edge('u1' , 'i1' ,color='orange',weight=7)

edges = G.edges()
colors_e_2 = [G[u][v]['color'] for u,v in edges]
# weights = [G[u][v]['weight'] for u,v in edges]

nx.draw_circular(G, edge_color=colors_e_2, node_color=colors_n,with_labels = True)

# %% [markdown]
# # part 3

# %%
num_of_nodes = 7
G = nx.Graph()

itemsi = [f'i{i}' for i in range(1,num_of_nodes+1)]
itemsj = [f'j{i}' for i in range(1,num_of_nodes+1)]


G.add_nodes_from(itemsi + itemsj )

colors_n = ['#f09409']*num_of_nodes + ['#00f4d0']*num_of_nodes 

pos = nx.random_layout(G) 
nx.draw(G, edge_color=colors_e,node_color=colors_n, pos=pos, width=weights,with_labels = True)

# %%
x = pos[list(G.nodes)[1]] - pos[list(G.nodes)[-1]]

# %%
x
# Out:
# array([ 0.10525537, -0.5992727 ], dtype=float32)

# %%
(x[0]**2 + x[1]**2)**0.5
# Out:
# 0.6084459667248294

# %%
G.remove_edges_from(G.edges())

for i in list(G.nodes)[0:7]:
  for j in list(G.nodes())[7:]:
    x = pos[i] - pos[j]
    d = (x[0]**2 + x[1]**2)**0.5
    
    if d< 0.25:
      G.add_edge(i,j ,color='orange')

# %%
edges = G.edges()
colors_e = [G[u][v]['color'] for u,v in edges]

# %%
nx.draw(G, edge_color=colors_e,node_color=colors_n, pos=pos,with_labels = True)

# %%
G.remove_edges_from(G.edges())

for i in list(G.nodes)[0:7]:
  ld = 10000
  for j in list(G.nodes())[7:]:
    x = pos[i] - pos[j]
    d = (x[0]**2 + x[1]**2)**0.5
    if d< ld : 
      ld = d
      jj = j
  G.add_edge(i,jj ,color='orange')

# %%
edges = G.edges()
colors_e = [G[u][v]['color'] for u,v in edges]

nx.draw(G, edge_color=colors_e,node_color=colors_n, pos=pos,with_labels = True)

# %% [markdown]
# # part 4

# %%
num_of_nodes = 10
G = nx.Graph()

itemsi = [f'i{i}' for i in range(1,num_of_nodes+1)]
itemsu = [f'u{i}' for i in range(1,num_of_nodes+1)]

G.add_nodes_from(itemsi + itemsu )

colors_n = ['#f09409']*num_of_nodes + ['#00f4d0']*num_of_nodes 
# shape = ['b']*num_of_nodes +  ['b']*num_of_nodes

# pos = nx.spring_layout(G) 
nx.draw(G, node_color=colors_n ,with_labels = True )

# %%
import random

edge_num = 15

G.remove_edges_from(G.edges())
for i in range(0,edge_num):
  a = random.randint(1,num_of_nodes)
  b = random.randint(1,num_of_nodes)
  a = f'i{a}'
  b = f'u{b}'
  G.add_edge(a , b ,color='blue',weight=2)


# G.add_edge(1,2,color='r',weight=2)
edges = G.edges()
colors_e = [G[u][v]['color'] for u,v in edges]
weights = [G[u][v]['weight'] for u,v in edges]

pos = nx.spring_layout(G) 
nx.draw(G, edge_color=colors_e,node_color=colors_n, pos=pos, width=weights,with_labels = True)
# nx.draw(G, edge_color=colors_e,node_color=colors_n ,width=weights,with_labels = True)

# %%
# Out:
# 'o'

# %%
nodeShapes
# Out:
# {'^', 'o', 'v'}

# %%
num_of_nodes = 100
G = nx.Graph()

itemsi = [f'i{i}' for i in range(1,num_of_nodes+1)]
itemsu = [f'u{i}' for i in range(1,num_of_nodes+1)]

G.add_nodes_from(itemsi + itemsu )

colors_n = ['#f09409']*num_of_nodes + ['#00f4d0']*num_of_nodes 
# shape = ['b']*num_of_nodes +  ['b']*num_of_nodes

# pos = nx.spring_layout(G) 
nx.draw_random(G, node_color=colors_n ,with_labels = True )
